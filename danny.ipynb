# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.__version__

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !tar -xvf "/content/drive/My Drive/商品影像AI辨識_初賽訓練資料/4710043001433.tar" -C "/content/sample_data/etdp_FileFolder/unzip/train"
# Out:
# 4710043001433/
# 4710043001433/Camera1/
# 4710043001433/Camera1/1/
# 4710043001433/Camera1/1/0.png
# 4710043001433/Camera1/1/0.xml
# 4710043001433/Camera1/1/1.png
# 4710043001433/Camera1/1/1.xml
# 4710043001433/Camera1/1/10.png
# 4710043001433/Camera1/1/10.xml
# 4710043001433/Camera1/1/11.png
# 4710043001433/Camera1/1/11.xml
# 4710043001433/Camera1/1/12.png
# 4710043001433/Camera1/1/12.xml
# 4710043001433/Camera1/1/13.png
# 4710043001433/Camera1/1/13.xml
# 4710043001433/Camera1/1/14.png
# 4710043001433/Camera1/1/14.xml
# 4710043001433/Camera1/1/15.png
# 4710043001433/Camera1/1/15.xml
# 4710043001433/Camera1/1/16.png
# 4710043001433/Camera1/1/16.xml
# 4710043001433/Camera1/1/17.png
# 4710043001433/Camera1/1/17.xml
# 4710043001433/Camera1/1/18.png
# 4710043001433/Camera1/1/18.xml
# 4710043001433/Camera1/1/19.png
# 4710043001433/Camera1/1/19.xml
# 4710043001433/Camera1/1/2.png
# 4710043001433/Camera1/1/2.xml
# 4710043001433/Camera1/1/20.png
# 4710043001433/Camera1/1/20.xml
# ...

# %%
! rm -rf '/content/sample_data/etdp_FileFolder/homography.py'

# %%
! mkdir "/content/drive/TRAIN_SET/"
# Out:
# mkdir: cannot create directory ‘/content/drive/TRAIN_SET/’: Operation not supported

# %%
! mv "/content/drive/My Drive/etdp_FileFolder"  "/content/sample_data"

# %%
! mkdir '/content/sample_data/etdp_FileFolder/unzip/test'

# %%
# !ls "/content"
# Out:
# drive  sample_data

# %%
z = !  ls '/content/drive/My Drive/商品影像AI辨識_初賽訓練資料'

# %%
z
# Out:
# [' 04003906.tar\t\t    4710298161234.tar   4719264904219.tar',
#  "'4710043001433 - bk0.tar'   4710423051096.tar   4719264904233.tar",
#  ' 4710043001433.tar\t    4710543006693.tar   4902777062013.tar',
#  ' 4710095046208.tar\t    4710594924427.tar   748675116052.tar',
#  ' 4710105030326.tar\t    4710626186519.tar   7610700600863.tar',
#  ' 4710126035003.tar\t    4710757030200.tar   8801111390064.tar',
#  ' 4710126041004.tar\t    4711162821520.tar   8886467102400.tar',
#  ' 4710126045460.tar\t    4711202224892.tar   8888077101101.tar',
#  ' 4710126100923.tar\t    4711402892921.tar   8888077102092.tar',
#  ' 4710128020106.tar\t    4713507024627.tar   README_20190805.txt',
#  ' 4710174114095.tar\t    4714431053110.tar']
